# %%
from IPython.display import Image, display

# %%
display(Image(filename='./img/0.jpeg'))

# %%
from PIL import Image
from IPython.display import display

# %%
from PIL import Image
from IPython.display import display
pil_im = Image.open('./imgrgba/8.jpeg')
display(pil_im)
newImage = pil_im.resize((150, 150))
display(newImage)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=368x274 at 0x1FA2A4B6D68>
# <PIL.Image.Image image mode=RGB size=150x150 at 0x1FA2A4B6DA0>

# %%
pil_im = Image.open('./img/0.jpeg').convert('L')
display(pil_im)
# Out:
# <PIL.Image.Image image mode=L size=426x303 at 0x20E2B666E10>

# %%
pil_im.thumbnail((50,50))

# %%
display(pil_im)
# Out:
# <PIL.Image.Image image mode=L size=50x35 at 0x20E2B666E10>

# %%
display(pil_im.resize((200,200)))
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x20E2B694160>

# %%
display(pil_im.rotate(45))
# Out:
# <PIL.Image.Image image mode=L size=50x35 at 0x20E2B6945C0>

# %%
from PIL import Image
from matplotlib.pyplot import *
import numpy as np
# %matplotlib inline

# %%
im = np.array(Image.open('./img/10.jpg'))
imshow(im)
x = [100, 100, 400, 400]
y = [200, 500, 200, 500]
plot(x, y, 'r*')
plot(x[:2], y[:2])
title('Ploting: "empire.jpg"')
axis('off')
show()

# %%
im = np.array(Image.open('./img/10.jpg').convert('L'))
figure()

gray()

contour(im, origin='image')
axis('equal')
axis('off')

figure()
hist(im.flatten(), 128)
show()

# %%
im = np.array(Image.open('./img/10.jpg'))
imshow(im)
print('please click three times')

x = ginput(3)
print('you clicked', x)

show()
# Out:
# please click three times
# d:\we\python35\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# you clicked []

# %%
from scipy.io import wavfile

# %%
audioName = './74325.wav'
result = wavfile.read(audioName)
print(result)
# Out:
# (8000, array([-12865, -18108,  -8639, ...,   -280,  -1216,  -1411], dtype=int16))
