# %%
# -*- coding:utf-8 -*-
from bs4 import BeautifulSoup
import urllib
from urllib.request import Request, urlopen, urlretrieve
import http
import time
import sys
import os
import json

# %%
data_root = '.'
class crawler:
    def __init__ (self, baeUrl, name, page, rn = 30, pn = 0, sleep = 0.1):
        self.name = urllib.parse.quote(name)
        self.baseUrl = baseUrl
        self.rn = rn
        self.pn = pn
        self.sleep = sleep
        self.count = 0
        self.page = page
    def getUrl (self):
        return self.baseUrl + ''.join(['&', 'queryWord', '=', self.name, '&', 'word', '=', self.name, '&', 'pn', '=', str(self.pn), '&', 'rn', '=', str(self.rn)])
    def downJson (self):
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:23.0) Gecko/20100101 Firefox/23.0'}
        req = Request(self.getUrl(), headers =  headers)
        res = urlopen(req)
        return res.read().decode('utf8')
    def parseUrlFromJson (self):
        urls = []
        try:
            json_data = json.loads(self.downJson())['data']
            for i in range(len(json_data)):
                replaceUrl = json_data[i]['replaceUrl']
                    for j in range(len(replaceUrl)):
                        urls.append(replaceUrl[j]['ObjURL'])
        except Exception as e:
            return urls
    def downImag(self):
        time.sleep(self.sleep)
        urls = self.parseUrlFromJson()
        for url in urls:
            try:
                subfix = url.split('.').pop()
                urlretrieve(url, os.path.join(data_root, 'img/' + str(self.count) + '.' + subfix ))
                self.count = self.count + 1
            except Exception as e:
                print(e)    
    def start(self):
        for i in range(self.page):
            self.pn = (i - 1) * self.rn
            self.downImag()

query = {
    'baseUrl': 'http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=&z=&ic=&s=&se=&tab=&width=&height=&face=&istype=&qc=&nc=&fr=',
    'pn': 0,
    'rn': 30,
    'sleep': 1,
    'name': '车牌',
    'page': 10
}

c = crawler(query['baseUrl'], query['name'], query['page'], query['rn'], query['pn'], query['sleep'])
c.start()
# Out:
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 502: Bad Gateway
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 503: Service Temporarily Unavailable
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 503: Service Temporarily Unavailable
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# [Errno 2] No such file or directory: '.\\img/45.cn/bmiddle/4f1094094444c055f77f2'
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# [WinError 10054] An existing connection was forcibly closed by the remote host
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-21-8c68230954d5> in <module>()
#      52
#      53 c = crawler(query['baseUrl'], query['name'], query['page'], query['rn'], query['pn'], query['sleep'])
# ---> 54 c.start()
#
# <ipython-input-21-8c68230954d5> in start(self)
#      40         for i in range(self.page):
#      41             self.pn = (i - 1) * self.rn
# ---> 42             self.downImag()
#      43
#      44 query = {
#
# <ipython-input-21-8c68230954d5> in downImag(self)
#      29     def downImag(self):
#      30         time.sleep(self.sleep)
# ---> 31         urls = self.parseUrlFromJson()
#      32         for url in urls:
#      33             try:
#
# <ipython-input-21-8c68230954d5> in parseUrlFromJson(self)
#      18     def parseUrlFromJson (self):
#      19         urls = []
# ---> 20         json_data = json.loads(self.downJson())['data']
#      21         for i in range(len(json_data)):
#      22             try:
#
# d:\we\python35\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# d:\we\python35\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# d:\we\python35\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid \escape: line 4 column 1430 (char 4441)
